# %%
# 直接使用bed生成的meta信息进行可视化

# %%
from nanomd.utils.abs_position import gene_feature_distance_calculator

# %%
bed_file="/home/cat10/projects/p1_packages/python/nanomd/data/ont_m6a_intersect.bed"
regions="/home/cat10/projects/p1_packages/python/nanomd/data/region_sizes.txt"
gfc_output="/home/cat10/projects/p1_packages/python/nanomd/data/ont_m6a_intersect_abs_dist.txt"
gfc = gene_feature_distance_calculator(bed_file, regions, gfc_output)
gfc.process_bed_file()
# Out:
# ** Total bedfile lines: 50876
# ** Excluded (features not well defined or gene not found in gtf): 4925
